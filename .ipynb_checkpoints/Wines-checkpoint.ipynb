# %% [markdown]
# # Analyze Wines

# %%
# Imports
import pandas as pd
import numpy as np
from datetime import datetime
import requests

# %%
import matplotlib.pyplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-351-864e826dab68> in <module>
# ----> 1 import matplotlib.pyplot
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in <module>
#      30 from cycler import cycler
#      31 import matplotlib
# ---> 32 import matplotlib.colorbar
#      33 import matplotlib.image
#      34 from matplotlib import rcsetup, style
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colorbar.py in <module>
#      25
#      26 import matplotlib as mpl
# ---> 27 import matplotlib.artist as martist
#      28 import matplotlib.cbook as cbook
#      29 import matplotlib.collections as collections
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in <module>
#      10
#      11 import matplotlib
# ---> 12 from . import cbook, docstring, rcParams
#      13 from .path import Path
#      14 from .transforms import (Bbox, IdentityTransform, Transform, TransformedBbox,
#
# ImportError: cannot import name 'rcParams' from 'matplotlib' (unknown location)

# %% [markdown]
# ### Part 1

# %%
regions = pd.read_csv("regions.csv")
print(f"Number of regions(Number of rows): {regions.shape[0]}")
# Out:
# Number of regions(Number of rows): 4353

# %%
regions["NomRegion"].values.sort()
regions
# Out:
#           NomRegion
# 0      Alpes du sud
# 1      Alpes du sud
# 2      Alpes du sud
# 3      Alpes du sud
# 4            Alsace
# ...             ...
# 4348  Vins du Monde
# 4349  Vins du Monde
# 4350  Vins du Monde
# 4351  Vins du Monde
# 4352  Vins du Monde
#
# [4353 rows x 1 columns]

# %%
# To remove the extra space in the end of the values
regions["NomRegion"] = [" ".join(i.split(" ")[:-1]) if i.endswith(" ") else i for i in regions["NomRegion"]]
# Since "Jura-Savoie" and "Provence-Corse" exist where "-" cannot be replaced with " "
# I do the below specific replaces

replaces = {"Languedoc-Roussillon" : "Languedoc Roussillon",
            "Languedoc" : "Languedoc Roussillon",
            "Sud-Ouest" : "Sud Ouest",
            "Vallée-de-la-Loire" : "Vallée de la Loire",
            "Vallée-du-Rhône" : "Vallée du Rhône",
            "Roussillon" : "Languedoc Roussillon",
            "Jura" : "Jura-Savoie",
            "Savoie" : "Jura-Savoie",
            "Monde" : "Vins du Monde",
            "Provence" : "Provence-Corse",
            "Corse" : "Provence-Corse"}
regions["NomRegion"].replace(replaces, inplace = True)

# %%
regions.drop_duplicates(inplace = True)
regions
# Out:
#                          NomRegion
# 0                     Alpes du sud
# 4                           Alsace
# 209                     Beaujolais
# 354                       Bordeaux
# 1375                     Bourgogne
# 1713                     Champagne
# 2065                Provence-Corse
# 2074                   Jura-Savoie
# 2096          Languedoc Roussillon
# 2671                         Loire
# 3013                      Lorraine
# 3017                 Vins du Monde
# 3367                         Rhône
# 3615                     Sud Ouest
# 3892                  Val de Loire
# 3967            Vallée de la Loire
# 3993  Vallée de la Loire et Centre
# 3996               Vallée du Rhône

# %% [markdown]
# ### Part 2

# %%
carrefour = pd.read_csv("Carrefour UTF8.csv")
print(f"Names of columns in carrefour dataset = \n{carrefour.columns.values}")
# Out:
# Names of columns in carrefour dataset =
# ['Producteur' 'AssemblageCepage' 'Millesime' 'Region' 'Pays' 'Contenance'
#  'ContenanceUnit' 'DegreeAlcool' 'appellation' 'CommBouche' 'CommOeil'
#  'CommNez' 'CommVin' 'Temperature' 'BestBefore' 'BestAfter' 'Prix'
#  'PrixDevise' 'DateCrawl' 'Couleur' 'UrlImage' 'UrlPageVin'
#  'UrlSiteSource' 'NomVin']

# %%
print(f"Number of Wines = {carrefour.shape[0]}")
# Out:
# Number of Wines = 1000

# %%
# Pre Cleaning
carrefour["Region"] = [str(i) for i in carrefour["Region"]]
carrefour["Region"] = [" ".join(i.split(" ")[:-1]) if i.endswith(" ") else i for i in carrefour["Region"]]
carrefour["Region"].replace(replaces, inplace = True)

# %%
regions_carrefour = pd.merge(regions, carrefour, how = "inner", left_on="NomRegion", right_on="Region")

# %%
# Cleaning the data
# Since I saw all the values in columns of "BestBefore" and "BestAfter" are nan
# I Assume we dont need the "PrixDevise"
regions_carrefour.drop(["PrixDevise", "NomRegion"], inplace=True, axis=1)

# %%
# Which varieties of wine are defined ?

# I'm not sure if this is correct
regions_carrefour[regions_carrefour["CommBouche"].notnull()]
# Out:
#                       Producteur  \
# 0    La Cave d'Augustin Florent
# 1     La Cave d'Augustin Florent
# 2            Cave de Ribeauvillé
# 3               Lucien Edelstein
# 4                Groupe Bestheim
# ..                           ...
# 990           Les Vins de Vienne
# 991                    E. Guigal
# 992                Maison Guigal
# 993                    E. Guigal
# 994                    E. Guigal
#
#                                  AssemblageCepage  Millesime           Region  \
# 0                                 Riesling (100%)       2016           Alsace
# 1                                        Sylvaner       2017           Alsace
# 2                                        Riesling       2015           Alsace
# 3                                             NaN       2016           Alsace
# 4                                        Riesling       2016           Alsace
# ..                                            ...        ...              ...
# 990                                         Syrah       2015  Vallée du Rhône
# 991  Grenache (70%), Syrah (20%), Mourvèdre (10%)       2013  Vallée du Rhône
# 992                                      Viognier       2016  Vallée du Rhône
# 993                                           NaN       2014  Vallée du Rhône
# 994                                  Syrah (100%)       2014  Vallée du Rhône
#
#        Pays  Contenance ContenanceUnit  DegreeAlcool   appellation  \
# 0    France        37.5             cl          12.0        Alsace
# 1    France        75.0             cl          12.0        Alsace
# 2    France        37.5             cl          13.0        Alsace
# 3    France        75.0             cl          12.0        Alsace
# 4    France        75.0             cl           0.0        Alsace
# ..      ...         ...            ...           ...           ...
# 990  France        75.0             cl          13.0  Saint-Joseph
# 991  France        75.0             cl          14.5      Gigondas
# 992  France        75.0             cl          13.0  Saint-Joseph
# 993  France        75.0             cl          14.5      Gigondas
# 994  France        75.0             cl           0.0  Saint-Joseph
#
#                                             CommBouche  ... Temperature  \
# 0           Une couleur jaune clair aux reflets verts.  ...         9.0
# 1                           Une jolie couleur or pâle.  ...         9.5
# 2    La robe est d'un jaune brillant aux reflets do...  ...         9.0
# 3                La robe est d'un jaune pâle et léger.  ...         9.0
# 4     La robe est d'un jaune pâle brillant et limpide.  ...         9.0
# ..                                                 ...  ...         ...
# 990  La robe est d'un rouge sombre aux reflets viol...  ...        17.0
# 991              Ce vin possède une belle robe pourpre  ...        18.0
# 992     La robe est d'un jaune pâle aux reflets verts.  ...        11.0
# 993              La robe est d'un rouge rubis pourpre.  ...        17.0
# 994                       Une belle robe rouge sombre.  ...        17.0
#
#     BestBefore BestAfter   Prix         DateCrawl  Couleur  \
# 0          NaN       NaN   3.05  12/10/2018 00:00    Blanc
# 1          NaN       NaN   3.50  12/10/2018 00:00    Blanc
regions_carrefour["Region"].value_counts().head(3)
# Out:
# Bordeaux                253
# Languedoc Roussillon    149
# Bourgogne               121
# Name: Region, dtype: int64

# %%
# Which query could be executed in order to build this plot?
# Pie Chart
round(regions_carrefour["Region"].value_counts()/len(regions_carrefour["Region"])*100, 2)
# Out:
# Bordeaux                        25.43
# Languedoc Roussillon            14.97
# Bourgogne                       12.16
# Provence-Corse                  11.96
# Vallée du Rhône                 10.85
# Val de Loire                     7.54
# Sud Ouest                        5.63
# Alsace                           4.42
# Champagne                        2.51
# Beaujolais                       1.91
# Jura-Savoie                      1.61
# Vins du Monde                    0.50
# Vallée de la Loire et Centre     0.30
# Vallée de la Loire               0.20
# Name: Region, dtype: float64

# %%
# Which query could be executed in order to build this plot? 
# Histogram plot
regions_carrefour["Region"].value_counts().sort_index().head(12)
# Out:
# Alsace                           44
# Beaujolais                       19
# Bordeaux                        253
# Bourgogne                       121
# Champagne                        25
# Jura-Savoie                      16
# Languedoc Roussillon            149
# Provence-Corse                  119
# Sud Ouest                        56
# Val de Loire                     75
# Vallée de la Loire                2
# Vallée de la Loire et Centre      3
# Name: Region, dtype: int64

# %%
regions_carrefour["Millesime"] = regions_carrefour["Millesime"].apply(lambda x: datetime.now().year if x==0 else x)

# %%
regions_carrefour.loc[regions_carrefour["Millesime"] == 0, :] = datetime.now().year

# %%
for_before_after = ["Bordeaux", "Bourgogne", "Alsace"]
top_3_regions = regions_carrefour[regions_carrefour["Region"].isin(for_before_after)]
top_3_regions
# Out:
#                       Producteur   AssemblageCepage  Millesime     Region  \
# 0    La Cave d'Augustin Florent     Riesling (100%)       2016     Alsace
# 1     La Cave d'Augustin Florent           Sylvaner       2017     Alsace
# 2            Cave de Ribeauvillé           Riesling       2015     Alsace
# 3               Lucien Edelstein                NaN       2016     Alsace
# 4                Groupe Bestheim           Riesling       2016     Alsace
# ..                           ...                ...        ...        ...
# 432     Lycée viticole de Beaune  Pinot noir (100%)       2016  Bourgogne
# 433           Jean-Marie Guffens  Chardonnay (100%)       2014  Bourgogne
# 434               Famille Bichot         Chardonnay       2016  Bourgogne
# 435                Jean Bouchard         Pinot noir       2010  Bourgogne
# 436                Jean Bouchard         Pinot noir       2015  Bourgogne
#
#        Pays  Contenance ContenanceUnit  DegreeAlcool         appellation  \
# 0    France        37.5             cl          12.0              Alsace
# 1    France        75.0             cl          12.0              Alsace
# 2    France        37.5             cl          13.0              Alsace
# 3    France        75.0             cl          12.0              Alsace
# 4    France        75.0             cl           0.0              Alsace
# ..      ...         ...            ...           ...                 ...
# 432  France        75.0             cl           0.0      Beaune 1er Cru
# 433  France        75.0             cl          13.0      Pouilly-Fuissé
# 434  France        75.0             cl          13.0    Montagny 1er Cru
# 435  France        75.0             cl          13.0  Savigny-Les-Beaune
# 436  France        75.0             cl          13.0               Fixin
#
#                                             CommBouche  ... Temperature  \
# 0           Une couleur jaune clair aux reflets verts.  ...         9.0
# 1                           Une jolie couleur or pâle.  ...         9.5
# 2    La robe est d'un jaune brillant aux reflets do...  ...         9.0
# 3                La robe est d'un jaune pâle et léger.  ...         9.0
# 4     La robe est d'un jaune pâle brillant et limpide.  ...         9.0
# ..                                                 ...  ...         ...
# [418 rows x 23 columns]

# %%
top_3_regions["Region"].unique()
# Out:
# array(['Alsace', 'Bordeaux', 'Bourgogne'], dtype=object)

# %%
top_3_regions[top_3_regions["Region"] == "Bordeaux", "BestAfter"] = top_3_regions["Millesime"] + 3
top_3_regions[top_3_regions["Region"] == "Bourgogne", "BestAfter"] = top_3_regions["Millesime"] + 5
top_3_regions[top_3_regions["Region"] == "Alsace", "BestAfter"] = top_3_regions["Millesime"] + 7

top_3_regions[top_3_regions["Region"] == "Bordeaux", "BestBefore"] = top_3_regions["Millesime"] + 7
top_3_regions[top_3_regions["Region"] == "Bourgogne", "BestBefore"] = top_3_regions["Millesime"] + 10
top_3_regions[top_3_regions["Region"] == "Alsace", "BestBefore"] = top_3_regions["Millesime"] + 4

top_3_regions
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                       Producteur   AssemblageCepage  Millesime     Region  \
# 0    La Cave d'Augustin Florent     Riesling (100%)       2016     Alsace
# 1     La Cave d'Augustin Florent           Sylvaner       2017     Alsace
# 2            Cave de Ribeauvillé           Riesling       2015     Alsace
# 3               Lucien Edelstein                NaN       2016     Alsace
# 4                Groupe Bestheim           Riesling       2016     Alsace
# ..                           ...                ...        ...        ...
# 432     Lycée viticole de Beaune  Pinot noir (100%)       2016  Bourgogne
# 433           Jean-Marie Guffens  Chardonnay (100%)       2014  Bourgogne
# 434               Famille Bichot         Chardonnay       2016  Bourgogne
# 435                Jean Bouchard         Pinot noir       2010  Bourgogne
# 436                Jean Bouchard         Pinot noir       2015  Bourgogne
#
#        Pays  Contenance ContenanceUnit  DegreeAlcool         appellation  \
# 0    France        37.5             cl          12.0              Alsace
# 1    France        75.0             cl          12.0              Alsace
# 2    France        37.5             cl          13.0              Alsace
# 3    France        75.0             cl          12.0              Alsace
# 4    France        75.0             cl           0.0              Alsace
# ..      ...         ...            ...           ...                 ...
# 432  France        75.0             cl           0.0      Beaune 1er Cru
# 433  France        75.0             cl          13.0      Pouilly-Fuissé
# 434  France        75.0             cl          13.0    Montagny 1er Cru
# 435  France        75.0             cl          13.0  Savigny-Les-Beaune
# 436  France        75.0             cl          13.0               Fixin
#
#                                             CommBouche  ... Temperature  \
# 0           Une couleur jaune clair aux reflets verts.  ...         9.0
# 1                           Une jolie couleur or pâle.  ...         9.5
# 2    La robe est d'un jaune brillant aux reflets do...  ...         9.0
# 3                La robe est d'un jaune pâle et léger.  ...         9.0
# 4     La robe est d'un jaune pâle brillant et limpide.  ...         9.0
# ..                                                 ...  ...         ...
# 432                La robe est d'un rouge rubis léger.  ...        15.0
# 433                          La robe est jaune claire.  ...        13.0
# 434  Sa couleur est d'un joli jaune clair aux refle...  ...        13.0
# 435  Une belle couleur rouge sombre aux reflets rubis.  ...        15.5
# 436             Une robe aux nuances de rubis intense.  ...        15.0
#
#     BestBefore BestAfter   Prix         DateCrawl  Couleur  \
# 0       2020.0    2023.0   3.05  12/10/2018 00:00    Blanc
# 1       2021.0    2024.0   3.50  12/10/2018 00:00    Blanc
# 2       2019.0    2022.0   4.30  12/10/2018 00:00    Blanc
# 3       2020.0    2023.0   4.35  12/10/2018 00:00    Blanc
# 4       2020.0    2023.0   4.65  12/10/2018 00:00    Blanc
# ..         ...       ...    ...               ...      ...
# 432     2026.0    2021.0  19.90  12/10/2018 00:00    Rouge
# 433     2024.0    2019.0  19.95  12/10/2018 00:00    Blanc
# 434     2026.0    2021.0  19.95  12/10/2018 00:00    Blanc
# 435     2020.0    2015.0  19.95  12/10/2018 00:00    Rouge
# 436     2025.0    2020.0  19.95  12/10/2018 00:00    Rouge
#
#                                               UrlImage  \
# 0    https://res.cloudinary.com/elixup/image/upload...
# 1    https://res.cloudinary.com/elixup/image/upload...
# 2    https://res.cloudinary.com/elixup/image/upload...
# 3    https://res.cloudinary.com/elixup/image/upload...
# 4    https://res.cloudinary.com/elixup/image/upload...
# ..                                                 ...
# 432  https://res.cloudinary.com/elixup/image/upload...
# 433  https://res.cloudinary.com/elixup/image/upload...
# 434  https://res.cloudinary.com/elixup/image/upload...
# 435  https://res.cloudinary.com/elixup/image/upload...
# 436  https://res.cloudinary.com/elixup/image/upload...
#
#                                             UrlPageVin  \
# 0    https://grandsvins.carrefour.fr/product/la-cav...
# 1    https://grandsvins.carrefour.fr/product/la-cav...
# 2    https://grandsvins.carrefour.fr/product/consta...
# 3    https://grandsvins.carrefour.fr/product/lucien...
# 4    https://grandsvins.carrefour.fr/product/maison...
# ..                                                 ...
# 432  https://grandsvins.carrefour.fr/product/domain...
# 433  https://grandsvins.carrefour.fr/product/terres...
# 434  https://grandsvins.carrefour.fr/product/jean-b...
# 435  https://grandsvins.carrefour.fr/product/jean-b...
# 436  https://grandsvins.carrefour.fr/product/jean-b...
#
#                        UrlSiteSource  \
# 0    https://grandsvins.carrefour.fr
# 1    https://grandsvins.carrefour.fr
# 2    https://grandsvins.carrefour.fr
# 3    https://grandsvins.carrefour.fr
# 4    https://grandsvins.carrefour.fr
# ..                               ...
# 432  https://grandsvins.carrefour.fr
# 433  https://grandsvins.carrefour.fr
# 434  https://grandsvins.carrefour.fr
# 435  https://grandsvins.carrefour.fr
# 436  https://grandsvins.carrefour.fr
#
#                                                 NomVin
# 0           La cave d'Augustin Florent "riesling" 2016
# 1     La Cave d'Augustin Florent "Sylvaner" Blanc 2017
# 2    Constance Muller Riesling "Reflets de France" ...
# 3                  Lucien Edelstein "Edelzwicker" 2016
# 4                            Maison Heim Riesling 2016
# ..                                                 ...
# 432         Domaine du Clos Saint-Philibert Rouge 2016
# 433             Maison Verget "Terres de Pierres" 2014
# 434  Jean Bouchard "Montagny 1er Cru" Tastevinage b...
# 435  Jean Bouchard "Savigny-Les-Beaune" rouge bio 2010
# 436                   Jean Bouchard "Fixin" rouge 2015
#
# [418 rows x 23 columns]

# %%
# Write a function called update_dates( dataframe) which receives a dataframe and udapte 
# “Millesime”, “BestBefore”, “BestAfter” columns 

key = 1
j = requests.get(f"http://micgiwines2019.azurewebsites.net/api/GetBestWines2019?key=Groupe{key}").json()
temp = pd.DataFrame(j)
temp
# Out:
#   appelation  millesime  percent
# 0  Bourgogne       2016       20
# 1      Corse       2016       20

# %%
def update_dates(df):
    
    df.loc[]
    
    return df

# %%
temp["temp"] = 0
temp.loc[temp["appelation"]=="Bourgogne", "temp"] = temp["millesime"]+7

# %%
temp
# Out:
#   appelation  millesime  percent  temp
# 0  Bourgogne       2016       20  2023
# 1      Corse       2016       20     0
