# %% [markdown]
# # Analyze Wines

# %%
# Imports
import pandas as pd
import numpy as np
from datetime import datetime
import requests
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## Part 1

# %%
regions = pd.read_csv("regions.csv")
print(f"Number of regions(Number of rows): {regions.shape[0]}")
# Out:
# Number of regions(Number of rows): 4353

# %%
regions["NomRegion"].values.sort()
regions
# Out:
#           NomRegion
# 0      Alpes du sud
# 1      Alpes du sud
# 2      Alpes du sud
# 3      Alpes du sud
# 4            Alsace
# ...             ...
# 4348  Vins du Monde
# 4349  Vins du Monde
# 4350  Vins du Monde
# 4351  Vins du Monde
# 4352  Vins du Monde
#
# [4353 rows x 1 columns]

# %% [markdown]
# ### Question 1

# %%
print("Number of regions defined = ", regions.shape[0])
# Out:
# Number of regions defined =  4353

# %%
# Cleaning the data

# To remove the extra space in the end of the values
regions["NomRegion"] = [" ".join(i.split(" ")[:-1]) if i.endswith(" ") else i for i in regions["NomRegion"]]

# Since "Jura-Savoie" and "Provence-Corse" exist where "-" cannot be replaced with " "
# I do the below specific replaces

replaces = {"Languedoc-Roussillon" : "Languedoc Roussillon",
            "Languedoc" : "Languedoc Roussillon",
            "Sud-Ouest" : "Sud Ouest",
            "Vallée-de-la-Loire" : "Vallée de la Loire",
            "Vallée-du-Rhône" : "Vallée du Rhône",
            "Roussillon" : "Languedoc Roussillon",
            "Jura" : "Jura-Savoie",
            "Savoie" : "Jura-Savoie",
            "Monde" : "Vins du Monde",
            "Provence" : "Provence-Corse",
            "Corse" : "Provence-Corse"}
regions["NomRegion"].replace(replaces, inplace = True)

# %%
regions.drop_duplicates(inplace = True)

# %% [markdown]
# ### Question 2

# %%
regions.sort_values(by="NomRegion")
# Out:
#                          NomRegion
# 0                     Alpes du sud
# 4                           Alsace
# 209                     Beaujolais
# 354                       Bordeaux
# 1375                     Bourgogne
# 1713                     Champagne
# 2074                   Jura-Savoie
# 2096          Languedoc Roussillon
# 2671                         Loire
# 3013                      Lorraine
# 2065                Provence-Corse
# 3367                         Rhône
# 3615                     Sud Ouest
# 3892                  Val de Loire
# 3967            Vallée de la Loire
# 3993  Vallée de la Loire et Centre
# 3996               Vallée du Rhône
# 3017                 Vins du Monde

# %% [markdown]
# ### Question 3

# %%
# To check the count regions
regions["NomRegion"].value_counts().sort_index()
# Out:
# Alpes du sud                    1
# Alsace                          1
# Beaujolais                      1
# Bordeaux                        1
# Bourgogne                       1
# Champagne                       1
# Jura-Savoie                     1
# Languedoc Roussillon            1
# Loire                           1
# Lorraine                        1
# Provence-Corse                  1
# Rhône                           1
# Sud Ouest                       1
# Val de Loire                    1
# Vallée de la Loire              1
# Vallée de la Loire et Centre    1
# Vallée du Rhône                 1
# Vins du Monde                   1
# Name: NomRegion, dtype: int64

# %% [markdown]
# ## Part 2

# %%
carrefour = pd.read_csv("Carrefour UTF8.csv")

# %% [markdown]
# ### Question 2

# %%
print(f"Names of columns in carrefour dataset = \n{carrefour.columns.values}")
# Out:
# Names of columns in carrefour dataset =
# ['Producteur' 'AssemblageCepage' 'Millesime' 'Region' 'Pays' 'Contenance'
#  'ContenanceUnit' 'DegreeAlcool' 'appellation' 'CommBouche' 'CommOeil'
#  'CommNez' 'CommVin' 'Temperature' 'BestBefore' 'BestAfter' 'Prix'
#  'PrixDevise' 'DateCrawl' 'Couleur' 'UrlImage' 'UrlPageVin'
#  'UrlSiteSource' 'NomVin']

# %% [markdown]
# ### Question 3

# %%
print(f"Number of Wines in the dataframe = {carrefour.shape[0]}")
# Out:
# Number of Wines in the dataframe = 1000

# %% [markdown]
# ### Question 2
# Clean the Carrefour data

# %%
# Pre Cleaning
carrefour["Region"] = [str(i) for i in carrefour["Region"]]
carrefour["Region"] = [" ".join(i.split(" ")[:-1]) if i.endswith(" ") else i for i in carrefour["Region"]]
carrefour["Region"].replace(replaces, inplace = True)

# %% [markdown]
# ### Question 1
# Merge carrefour with regions

# %%
regions_carrefour = pd.merge(regions, carrefour, how = "inner", left_on="NomRegion", right_on="Region")
regions_carrefour["Site"] = "Carrefour"

# %% [markdown]
# ### Question 3
# Variety of wines defined

# %%
# Which varieties of wine are defined ?
# Just printing the first 10 since there are 279 unique wines 
regions_carrefour["AssemblageCepage"].unique()[:10]
# Out:
# array(['Riesling (100%)', 'Sylvaner', 'Riesling', nan, 'Pinot noir',
#        'Riesling, Pinot noir, Pinot Blanc', 'Riesling ', 'Gewurztraminer',
#        'Pinot Gris', 'Riesling, Pinot Blanc, Pinot Gris'], dtype=object)

# %% [markdown]
# ### Question 5
# Which wines from burgundy have their price over 19?

# %%
# Wines from Burgundy and costing more than €19
regions_carrefour[(regions_carrefour["Region"] == "Bourgogne") & (regions_carrefour["Prix"] > 19)]
# Out:
#      NomRegion                Producteur   AssemblageCepage  Millesime  \
# 430  Bourgogne        Domaine et Château         Pinot noir       2015
# 431  Bourgogne       Maison Louis Latour  Chardonnay (100%)       2010
# 432  Bourgogne  Lycée viticole de Beaune  Pinot noir (100%)       2016
# 433  Bourgogne        Jean-Marie Guffens  Chardonnay (100%)       2014
# 434  Bourgogne            Famille Bichot         Chardonnay       2016
# 435  Bourgogne             Jean Bouchard         Pinot noir       2010
# 436  Bourgogne             Jean Bouchard         Pinot noir       2015
#
#         Region    Pays  Contenance ContenanceUnit  DegreeAlcool  \
# 430  Bourgogne  France        75.0             cl           0.0
# 431  Bourgogne  France        75.0             cl           0.0
# 432  Bourgogne  France        75.0             cl           0.0
# 433  Bourgogne  France        75.0             cl          13.0
# 434  Bourgogne  France        75.0             cl          13.0
# 435  Bourgogne  France        75.0             cl          13.0
# 436  Bourgogne  France        75.0             cl          13.0
#
#              appellation  ... BestAfter   Prix PrixDevise         DateCrawl  \
# 430  Pernand-Vergelesses  ...       NaN  19.80          €  12/10/2018 00:00
# 431          Saint-Aubin  ...       NaN  19.90          €  12/10/2018 00:00
# 432       Beaune 1er Cru  ...       NaN  19.90          €  12/10/2018 00:00
# 433       Pouilly-Fuissé  ...       NaN  19.95          €  12/10/2018 00:00
# 434     Montagny 1er Cru  ...       NaN  19.95          €  12/10/2018 00:00
# 435   Savigny-Les-Beaune  ...       NaN  19.95          €  12/10/2018 00:00
# 436                Fixin  ...       NaN  19.95          €  12/10/2018 00:00
#
#      Couleur                                           UrlImage  \
# 430    Rouge  https://res.cloudinary.com/elixup/image/upload...
# 431    Blanc  https://res.cloudinary.com/elixup/image/upload...
# 432    Rouge  https://res.cloudinary.com/elixup/image/upload...
# 433    Blanc  https://res.cloudinary.com/elixup/image/upload...
# 434    Blanc  https://res.cloudinary.com/elixup/image/upload...
# 435    Rouge  https://res.cloudinary.com/elixup/image/upload...
# 436    Rouge  https://res.cloudinary.com/elixup/image/upload...
#
#                                             UrlPageVin  \
# 430  https://grandsvins.carrefour.fr/product/75-aoc...
# 431  https://grandsvins.carrefour.fr/product/75-aoc...
# 432  https://grandsvins.carrefour.fr/product/domain...
# 433  https://grandsvins.carrefour.fr/product/terres...
# 434  https://grandsvins.carrefour.fr/product/jean-b...
# 435  https://grandsvins.carrefour.fr/product/jean-b...
# 436  https://grandsvins.carrefour.fr/product/jean-b...
#
#                        UrlSiteSource  \
# 430  https://grandsvins.carrefour.fr
# 431  https://grandsvins.carrefour.fr
# 432  https://grandsvins.carrefour.fr
# 433  https://grandsvins.carrefour.fr
# 434  https://grandsvins.carrefour.fr
# 435  https://grandsvins.carrefour.fr
# 436  https://grandsvins.carrefour.fr
#
#                                                 NomVin       Site
# 430                       Domaine Virginie Pillet 2015  Carrefour
# 431                           Maison Louis Latour 2010  Carrefour
# 432         Domaine du Clos Saint-Philibert Rouge 2016  Carrefour
# 433             Maison Verget "Terres de Pierres" 2014  Carrefour
# 434  Jean Bouchard "Montagny 1er Cru" Tastevinage b...  Carrefour
# 435  Jean Bouchard "Savigny-Les-Beaune" rouge bio 2010  Carrefour
# 436                   Jean Bouchard "Fixin" rouge 2015  Carrefour
#
# [7 rows x 26 columns]

# %% [markdown]
# ### Question 6
# What are the top three most common regions?

# %%
# what are the top three most common regions?
regions_carrefour["Region"].value_counts().head(3)
# Out:
# Bordeaux                253
# Languedoc Roussillon    149
# Bourgogne               121
# Name: Region, dtype: int64

# %% [markdown]
# ### Question 1
# Which query could be executed in order to build this plot (Pie Chart)?

# %%
# Which query could be executed in order to build this plot?
# Pie Chart
round(regions_carrefour["Region"].value_counts()/len(regions_carrefour["Region"])*100, 2)
# Out:
# Bordeaux                        25.43
# Languedoc Roussillon            14.97
# Bourgogne                       12.16
# Provence-Corse                  11.96
# Vallée du Rhône                 10.85
# Val de Loire                     7.54
# Sud Ouest                        5.63
# Alsace                           4.42
# Champagne                        2.51
# Beaujolais                       1.91
# Jura-Savoie                      1.61
# Vins du Monde                    0.50
# Vallée de la Loire et Centre     0.30
# Vallée de la Loire               0.20
# Name: Region, dtype: float64

# %%
def pie(series, y_label = "", explode = False, title = "", x_label = ""):
    #explode = [0.1 if i%2==0 else 0 for i in range(len(series.value_counts())) ]
    plot_explode = [0 for i in range(len(series.value_counts()))]
    if explode:
        plot_explode[1] = 0.2
    plt.figure(figsize=(10, 10))
    plt.pie(x = series.value_counts(),
            labels = series.value_counts().index,
            autopct = "%.2f%%",
            explode = plot_explode)
    plt.ylabel(f'{y_label}')
    plt.xlabel(f'{x_label}')
    plt.title(f"{title}")
    plt.show()

# %%
pie(regions_carrefour["Region"])
#[0 for i in range(len(regions_carrefour["Region"]))]

# %% [markdown]
# ### Question 1
# Which query could be executed in order to build this plot (Bar chart)?

# %%
temp = regions_carrefour["Region"].value_counts().sort_index().head(12)
plt.bar(temp.index, temp.values)
plt.xticks(rotation = 90);

# %% [markdown]
# ### Question
# Setting missing or values of 0 in Millesime to current year

# %%
regions_carrefour.loc[regions_carrefour["Millesime"] == 0, "Millesime"] = datetime.now().year

# %% [markdown]
# ### Question
# Subsetting the dataframe based on the three regions for which we can obtain the BestBefore and BestAfter values

# %%
for_before_after = ["Bordeaux", "Bourgogne", "Alsace"]
top_3_regions = regions_carrefour[regions_carrefour["Region"].isin(for_before_after)]
top_3_regions
# Out:
#      NomRegion                   Producteur   AssemblageCepage  Millesime  \
# 0       Alsace  La Cave d'Augustin Florent     Riesling (100%)       2016
# 1       Alsace   La Cave d'Augustin Florent           Sylvaner       2017
# 2       Alsace          Cave de Ribeauvillé           Riesling       2015
# 3       Alsace             Lucien Edelstein                NaN       2016
# 4       Alsace              Groupe Bestheim           Riesling       2016
# ..         ...                          ...                ...        ...
# 432  Bourgogne     Lycée viticole de Beaune  Pinot noir (100%)       2016
# 433  Bourgogne           Jean-Marie Guffens  Chardonnay (100%)       2014
# 434  Bourgogne               Famille Bichot         Chardonnay       2016
# 435  Bourgogne                Jean Bouchard         Pinot noir       2010
# 436  Bourgogne                Jean Bouchard         Pinot noir       2015
#
#         Region    Pays  Contenance ContenanceUnit  DegreeAlcool  \
# 0       Alsace  France        37.5             cl          12.0
# 1       Alsace  France        75.0             cl          12.0
# 2       Alsace  France        37.5             cl          13.0
# 3       Alsace  France        75.0             cl          12.0
# 4       Alsace  France        75.0             cl           0.0
# ..         ...     ...         ...            ...           ...
# 432  Bourgogne  France        75.0             cl           0.0
# 433  Bourgogne  France        75.0             cl          13.0
# 434  Bourgogne  France        75.0             cl          13.0
# 435  Bourgogne  France        75.0             cl          13.0
# 436  Bourgogne  France        75.0             cl          13.0
#
#             appellation  ... BestAfter   Prix PrixDevise         DateCrawl  \
# 0                Alsace  ...       NaN   3.05          €  12/10/2018 00:00
# 1                Alsace  ...       NaN   3.50          €  12/10/2018 00:00
# 2                Alsace  ...       NaN   4.30          €  12/10/2018 00:00
# 3                Alsace  ...       NaN   4.35          €  12/10/2018 00:00
# 4                Alsace  ...       NaN   4.65          €  12/10/2018 00:00
# ..                  ...  ...       ...    ...        ...               ...
# 432      Beaune 1er Cru  ...       NaN  19.90          €  12/10/2018 00:00
# 433      Pouilly-Fuissé  ...       NaN  19.95          €  12/10/2018 00:00
# 434    Montagny 1er Cru  ...       NaN  19.95          €  12/10/2018 00:00
# 435  Savigny-Les-Beaune  ...       NaN  19.95          €  12/10/2018 00:00
# 436               Fixin  ...       NaN  19.95          €  12/10/2018 00:00
#
#      Couleur                                           UrlImage  \
# 0      Blanc  https://res.cloudinary.com/elixup/image/upload...
# 1      Blanc  https://res.cloudinary.com/elixup/image/upload...
# 2      Blanc  https://res.cloudinary.com/elixup/image/upload...
# 3      Blanc  https://res.cloudinary.com/elixup/image/upload...
# 4      Blanc  https://res.cloudinary.com/elixup/image/upload...
# ..       ...                                                ...
# 432    Rouge  https://res.cloudinary.com/elixup/image/upload...
# 433    Blanc  https://res.cloudinary.com/elixup/image/upload...
# 434    Blanc  https://res.cloudinary.com/elixup/image/upload...
# 435    Rouge  https://res.cloudinary.com/elixup/image/upload...
# 436    Rouge  https://res.cloudinary.com/elixup/image/upload...
#
#                                             UrlPageVin  \
# 0    https://grandsvins.carrefour.fr/product/la-cav...
# 1    https://grandsvins.carrefour.fr/product/la-cav...
# 2    https://grandsvins.carrefour.fr/product/consta...
# 3    https://grandsvins.carrefour.fr/product/lucien...
# 4    https://grandsvins.carrefour.fr/product/maison...
# ..                                                 ...
# 432  https://grandsvins.carrefour.fr/product/domain...
# 433  https://grandsvins.carrefour.fr/product/terres...
# 434  https://grandsvins.carrefour.fr/product/jean-b...
# 435  https://grandsvins.carrefour.fr/product/jean-b...
# 436  https://grandsvins.carrefour.fr/product/jean-b...
#
#                        UrlSiteSource  \
# 0    https://grandsvins.carrefour.fr
# 1    https://grandsvins.carrefour.fr
# 2    https://grandsvins.carrefour.fr
# 3    https://grandsvins.carrefour.fr
# 4    https://grandsvins.carrefour.fr
# ..                               ...
# 432  https://grandsvins.carrefour.fr
# 433  https://grandsvins.carrefour.fr
# 434  https://grandsvins.carrefour.fr
# 435  https://grandsvins.carrefour.fr
# 436  https://grandsvins.carrefour.fr
#
#                                                 NomVin       Site
# 0           La cave d'Augustin Florent "riesling" 2016  Carrefour
# 1     La Cave d'Augustin Florent "Sylvaner" Blanc 2017  Carrefour
# 2    Constance Muller Riesling "Reflets de France" ...  Carrefour
# 3                  Lucien Edelstein "Edelzwicker" 2016  Carrefour
# 4                            Maison Heim Riesling 2016  Carrefour
# ..                                                 ...        ...
# 432         Domaine du Clos Saint-Philibert Rouge 2016  Carrefour
# 433             Maison Verget "Terres de Pierres" 2014  Carrefour
# 434  Jean Bouchard "Montagny 1er Cru" Tastevinage b...  Carrefour
# 435  Jean Bouchard "Savigny-Les-Beaune" rouge bio 2010  Carrefour
# 436                   Jean Bouchard "Fixin" rouge 2015  Carrefour
#
# [418 rows x 26 columns]

# %%
top_3_regions["Region"].unique()
# Out:
# array(['Alsace', 'Bordeaux', 'Bourgogne'], dtype=object)

# %%
top_3_regions.loc[top_3_regions["Region"] == "Bordeaux", "BestAfter"] = top_3_regions["Millesime"] + 3
top_3_regions.loc[top_3_regions["Region"] == "Bourgogne", "BestAfter"] = top_3_regions["Millesime"] + 5
top_3_regions.loc[top_3_regions["Region"] == "Alsace", "BestAfter"] = top_3_regions["Millesime"] + 1

top_3_regions.loc[top_3_regions["Region"] == "Bordeaux", "BestBefore"] = top_3_regions["Millesime"] + 7
top_3_regions.loc[top_3_regions["Region"] == "Bourgogne", "BestBefore"] = top_3_regions["Millesime"] + 10
top_3_regions.loc[top_3_regions["Region"] == "Alsace", "BestBefore"] = top_3_regions["Millesime"] + 4

top_3_regions
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#                                                 NomVin       Site
# 0           La cave d'Augustin Florent "riesling" 2016  Carrefour
# 2    Constance Muller Riesling "Reflets de France" ...  Carrefour
# 3                  Lucien Edelstein "Edelzwicker" 2016  Carrefour
# 4                            Maison Heim Riesling 2016  Carrefour
# 6         La Cave d'Augustin Florent "pinot gris" 2016  Carrefour
# ..                                                 ...        ...
# 313                            Château Tour Seran 2011  Carrefour
# 314                   Château Bibian Rouge 2012 Magnum  Carrefour
# 415                  Maison Louis Latour "Beaune" 2007  Carrefour
# 431                           Maison Louis Latour 2010  Carrefour
# 435  Jean Bouchard "Savigny-Les-Beaune" rouge bio 2010  Carrefour
#
# [95 rows x 26 columns]

# %% [markdown]
# ### Question
# Write a function called update_dates( dataframe) which receives a dataframe and udapte the prices of the wines mentioned with the percentages you get

# %%
key = 2

def update_dates(df):
    df.loc[df["millesime"] == 0] = datetime.now().year
    
    df.loc[df["appelation"] == "Bordeaux", "BestAfter"] = df["millesime"] + 3
    df.loc[df["appelation"] == "Bourgogne", "BestAfter"] = df["millesime"] + 5
    df.loc[df["appelation"] == "Alsace", "BestAfter"] = df["millesime"] + 1

    df.loc[df["appelation"] == "Bordeaux", "BestBefore"] = df["millesime"] + 7
    df.loc[df["appelation"] == "Bourgogne", "BestBefore"] = df["millesime"] + 10
    df.loc[df["appelation"] == "Alsace", "BestBefore"] = df["millesime"] + 4

    df.fillna(0, inplace=True)
    df[["BestBefore", "BestAfter"]] = df[["BestBefore", "BestAfter"]].astype(int)
    return df

j = requests.get(f"http://micgiwines2019.azurewebsites.net/api/GetBestWines2019?key=Groupe{key}").json()
temp = pd.DataFrame(j)

update_dates(temp)
# Out:
#   appelation  millesime  percent  BestAfter  BestBefore
# 0  Bourgogne       2016        5       2021        2026
# 1      Corse       2016        5          0           0

# %% [markdown]
# ## Part 3

# %% [markdown]
# ### Question 1

# %%
site = pd.read_csv("Site 4 11 OK.csv")

# %% [markdown]
# ### Question 2
# Add the column "Site"

# %%
site["Site"] = "site4"

# %% [markdown]
# ### Question 3
# Cleaning data

# %%
site.drop(site.columns[[0, 5, 9, 12, 15, 16, 17, 18, 20, 21, 27, 28, 29, 31, 32, 33, 35, 36, 37, 38, 40, 47, 53]], 
          axis = 1, 
          inplace=True)
site.rename({'NomRegion': "Region"}, axis = 1, inplace = True)
site["Region"].replace(replaces, inplace=True)

# %% [markdown]
# ### Question 4
# How many varieties are there

# %%
len(site["AssemblageCepage"].unique())
# Out:
# 1270

# %% [markdown]
# ### Question 5
# Merge with the first dataframe

# %%
region_site = pd.merge(regions, site, how="inner", left_on="NomRegion", right_on="Region")

# %% [markdown]
# ### Question 6
# Concatenate the Carrefour and Site4 dataset

# %%
concat = pd.concat([region_site, regions_carrefour])

# %% [markdown]
# ### Question 7
# Pie Chart to know percentage of wine present in each data set

# %%
round(concat["Site"].value_counts()/len(concat)*100, 2)
pie(concat["Site"], y_label="Region", explode=True)

# %%
temp = concat["Region"].value_counts().sort_index()
plt.barh(y = temp.index, width = temp.values)
plt.ylabel("Region");
